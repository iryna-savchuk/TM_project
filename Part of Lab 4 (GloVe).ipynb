# %% [markdown]
# # Experimenting with GloVe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

import string
import re
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

from sklearn.preprocessing import StandardScaler

import demoji

# %% [markdown]
# # Data Import

# %%
df_train_raw = pd.read_excel('Project Corpora/train.xlsx')

# %%
df_train_raw.head(5)
# Out:
#    index                                        description
# 0      1  This is a shared mixed room in our hostel, wit...  \
# 1      2  O meu espaço fica perto de Parque Eduardo VII,...
# 2      3  Trafaria’s House is a cozy and familiar villa ...
# 3      4  Apartamento Charmoso no Chiado, Entre o Largo ...
# 4      5  Joli appartement  en bordure de mer.<br /> 2 m...
#
#                                           host_about  unlisted
# 0                Alojamento Local Registro: 20835/AL         0
# 1  I am friendly host, and I will try to always b...         1
# 2  I am a social person liking to communicate, re...         1
# 3  Hello!_x000D_\nI m Portuguese and i love to me...         0
# 4  Nous sommes une famille avec deux enfants de 1...         0

# %% [markdown]
# # Preprocesssing

# %% [markdown]
# ## Splitting data into Train and Validation

# %%
# Split the original train dataframe into training and validation sets
train_df, val_df = train_test_split(df_train_raw, test_size=0.2, random_state=42, 
                                    stratify=df_train_raw['unlisted']) # using stratify, to keep classes proportion

print('Shapes of train_df', train_df.shape)
print('Shapes of val_df', val_df.shape)
# Out:
# Shapes of train_df (9996, 4)
# Shapes of val_df (2500, 4)

# %% [markdown]
# ## Preprocessing: cleaning, stemming, lemmatization

# %%
stop = set(stopwords.words('english'))
stemmer = SnowballStemmer('english')
lemma = WordNetLemmatizer()

# %%
def clean(text_list, lemmatize, stemmer):   
    cleaned_text_list = []  
    text_list.fillna('', inplace=True)
    for text in tqdm(text_list):           
        #LOWERCASE TEXT
        text = text.lower()
        
        #Converting emoji to their description
        text = demoji.replace_with_desc(text)

        #REMOVE NUMERICAL DATA and PUNCTUATION
        text = re.sub("[^a-zA-Z]"," ", text )
        text = re.sub("br", "", text)

        #REMOVE STOPWORDS
        text = " ".join([word for word in text.split() if word not in stop])

        #Lemmatize
        if lemmatize:
            text = " ".join(lemma.lemmatize(word) for word in text.split())

        #Stemming
        if stemmer:
            text = " ".join(stemmer.stem(word) for word in text.split())

        cleaned_text_list.append(text)        
    return cleaned_text_list

# %%
train_df['cleaned_description'] = clean(train_df['description'], lemmatize = True, stemmer = False)
train_df.head(3)
# Out:
# 100%|██████████████████████████████████████| 9996/9996 [00:24<00:00, 403.21it/s]
#        index                                        description
# 7712    7713  This exclusive villa, located in a quiet pinew...  \
# 11333  11334  Luna House B&B is part of the Luna House Hub, ...
# 3536    3537  Newly refurbished apartment with swimming pool...
#
#                                               host_about  unlisted
# 7712   We are a couple with a big family and we love ...         0  \
# 11333  Luna House B&B is part of the Luna House Hub, ...         1
# 3536   World citizen looking forward to meet new peop...         0
#
#                                      cleaned_description
# 7712   exclusive villa located quiet pinewood area co...
# 11333  luna house b b part luna house hub located clo...
# 3536   newly refurbished apartment swimming pool stun...

# %%
val_df["cleaned_description"] = clean(val_df['description'], lemmatize = True, stemmer = False)
# Out:
# 100%|██████████████████████████████████████| 2500/2500 [00:05<00:00, 417.49it/s]

# %%
x_train = train_df["cleaned_description"]
y_train = train_df['unlisted']

x_val = val_df["cleaned_description"]
y_val = val_df['unlisted']

# %% [markdown]
# # GloVe

# %%
import torch
import torchtext.vocab as vocab

dim = 50
glove = vocab.GloVe(name='6B', dim=dim)
print('Loaded {} words'.format(len(glove.itos)))
# Out:
# Loaded 400000 words

# %%
def get_word_vector(word):
    try:
        vector = glove.vectors[glove.stoi[word]]
    except KeyError:
        vector = np.zeros(dim) # Word not found in glove, return a vector of zeros
    return vector


def get_sentence_vector(sentence):
    if isinstance(sentence, str) and len(sentence)>0:
        words = sentence.split()
        #vectors = [get_word_vector(word) for word in words]   
        # Convert the list of arrays into a single NumPy array
        vectors = np.stack([get_word_vector(word) for word in words], axis=0)
        return np.sum(vectors, axis=0)
    else: 
        return np.zeros(dim)

# %%
get_sentence_vector("hello world")
# Out:
# array([-7.9983002e-01,  1.5194000e+00, -2.4039401e-01,  5.9090006e-01,
#         1.9765100e-01, -9.1020000e-01, -1.0181900e+00, -5.6529999e-01,
#         2.8090003e-01,  4.3883997e-01,  6.5774697e-01,  7.9752004e-01,
#        -7.1718001e-01,  1.0763099e+00,  2.0495999e+00, -2.8243899e-01,
#        -1.3227999e-01,  1.1734600e+00, -1.1429399e+00, -2.1970500e-01,
#        -8.3416998e-02,  5.8233696e-01,  1.9599000e-01,  6.0697001e-01,
#         1.6761701e+00, -2.2946100e+00, -1.7676101e+00, -5.2259982e-02,
#         9.7130001e-02, -7.7643001e-01,  4.1070199e+00,  1.2023300e+00,
#        -5.3263497e-01,  6.8708003e-01, -1.8596300e+00, -4.6874002e-01,
#         2.5179002e-01, -2.9832995e-01, -9.1472304e-01, -1.3504100e+00,
#        -8.1759989e-02, -1.0369600e+00,  4.5438004e-01, -8.9336997e-01,
#         1.0484800e+00,  8.7687999e-01, -1.4907101e-01, -1.0367600e+00,
#        -3.2755700e-01, -3.3800006e-03], dtype=float32)

# %%
x_train_glove = np.array([get_sentence_vector(text) for text in x_train])
x_val_glove =  np.array([get_sentence_vector(text) for text in x_val])

# %%
# Scaling selected columns with MinMaxScaler
scaler = StandardScaler()

x_train_glove_scaled = scaler.fit_transform(x_train_glove)
x_val_glove_scaled = scaler.transform(x_val_glove)

# %% [markdown]
# # Train Classifier

# %%
modelknn = KNeighborsClassifier(n_neighbors = 7, 
                                metric = 'cosine', 
                                weights = 'distance')

# %%
modelknn.fit(x_train_glove_scaled, y_train)
# Out:
# KNeighborsClassifier(metric='cosine', n_neighbors=7, weights='distance')

# %% [markdown]
# # Predict for Val corpus

# %%
y_pred = modelknn.predict(x_val_glove_scaled)

# %% [markdown]
# # Evaluate

# %%
def plot_cm(confusion_matrix : np.array, 
            classnames : list):
    """
    Function that creates a confusion matrix plot using the Wikipedia convention for the axis. 
    :param confusion_matrix: confusion matrix that will be plotted
    :param classnames: labels of the classes
    
    Returns:
        - Plot of the Confusion Matrix
    """
    
    confusionmatrix = confusion_matrix
    class_names = classnames             

    fig, ax = plt.subplots()
    im = plt.imshow(confusionmatrix, cmap=plt.cm.cividis)
    plt.colorbar()

    # We want to show all ticks...
    ax.set_xticks(np.arange(len(class_names)))
    ax.set_yticks(np.arange(len(class_names)))
    # ... and label them with the respective list entries
    ax.set_xticklabels(class_names)
    ax.set_yticklabels(class_names)

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    for i in range(len(class_names)):
        for j in range(len(class_names)):
            text = ax.text(j, i, confusionmatrix[i, j],
                           ha="center", va="center", color="w")

    ax.set_title("Confusion Matrix")
    plt.xlabel('Targets')
    plt.ylabel('Predictions')
    #plt.ylim(top=len(class_names)-0.5)  # adjust the top leaving bottom unchanged
    #plt.ylim(bottom=-0.5)  # adjust the bottom leaving top unchanged
    return plt.show()

# %%
labels = {"listed":0, "unlisted":1}
print(classification_report(y_pred, y_val, target_names = labels.keys()))

plot_cm(confusion_matrix(y_pred, y_val), labels.keys())
# Out:
#               precision    recall  f1-score   support
#
#       listed       0.90      0.80      0.85      2025
#     unlisted       0.42      0.61      0.49       475
#
#     accuracy                           0.76      2500
#    macro avg       0.66      0.70      0.67      2500
# weighted avg       0.81      0.76      0.78      2500

# %% [markdown]
# # Extending Features with Reviews

# %%
train_df.head(3)
# Out:
#        index                                        description
# 7712    7713  This exclusive villa, located in a quiet pinew...  \
# 11333  11334  Luna House B&B is part of the Luna House Hub, ...
# 3536    3537  Newly refurbished apartment with swimming pool...
#
#                                               host_about  unlisted
# 7712   We are a couple with a big family and we love ...         0  \
# 11333  Luna House B&B is part of the Luna House Hub, ...         1
# 3536   World citizen looking forward to meet new peop...         0
#
#                                      cleaned_description
# 7712   exclusive villa located quiet pinewood area co...
# 11333  luna house b b part luna house hub located clo...
# 3536   newly refurbished apartment swimming pool stun...

# %%
train_df['description_vectors'] = train_df['cleaned_description'].apply(get_sentence_vector)
train_df.head(3)
# Out:
#        index                                        description
# 7712    7713  This exclusive villa, located in a quiet pinew...  \
# 11333  11334  Luna House B&B is part of the Luna House Hub, ...
# 3536    3537  Newly refurbished apartment with swimming pool...
#
#                                               host_about  unlisted
# 7712   We are a couple with a big family and we love ...         0  \
# 11333  Luna House B&B is part of the Luna House Hub, ...         1
# 3536   World citizen looking forward to meet new peop...         0
#
#                                      cleaned_description
# 7712   exclusive villa located quiet pinewood area co...  \
# 11333  luna house b b part luna house hub located clo...
# 3536   newly refurbished apartment swimming pool stun...
#
#                                      description_vectors
# 7712   [35.13662564801052, 42.947640486992896, -1.106...
# 11333  [34.154502129531465, 34.9295552438125, -8.8469...
# ...

# %%
# Splitting description_vectors
new_cols = pd.DataFrame(train_df['description_vectors'].apply(pd.Series).values.tolist(), 
                        columns=['v_'+str(i+1) for i in range(50)])

new_cols
# Out:
#             v_1        v_2        v_3        v_4        v_5        v_6
# 0     35.136626  42.947640  -1.106369  -2.959592  35.337361 -24.277150  \
# 1     34.154502  34.929555  -8.846930  -7.521545  36.360019 -10.971707
# 2     40.250266  34.652338  -6.978866   1.241263  11.868687 -34.835922
# 3     40.432363  40.645558  -4.705836  -3.481639  21.099667 -21.982438
# 4     34.680662  24.131606  -1.834198 -14.697037   7.813480 -13.023907
# ...         ...        ...        ...        ...        ...        ...
# 9991  37.436634  40.390122 -11.201662  -8.903486   9.701048 -27.973777
# 9992  19.744406  28.070294  -6.992010  -6.261276  34.344053 -11.441753
# 9993  30.248591  37.528913   7.563411  -8.391753  23.839268 -18.109397
# 9994  32.931900  35.911243 -23.939777  -2.709645  24.472498 -31.184864
# 9995  20.011257  33.370648   4.731375   8.596707   8.007117 -17.548384
#
#             v_7        v_8        v_9       v_10  ...       v_41       v_42
# ...

# %%
train_df.shape
# Out:
# (9996, 6)

# %%
new_cols.shape
# Out:
# (9996, 50)

# %%
# Concatenate horizontally (along axis=1) with different indexes
combined_df = pd.concat([train_df.reset_index(drop=True), new_cols.reset_index(drop=True)], axis=1)
combined_df.head(3)
# Out:
#    index                                        description
# 0   7713  This exclusive villa, located in a quiet pinew...  \
# 1  11334  Luna House B&B is part of the Luna House Hub, ...
# 2   3537  Newly refurbished apartment with swimming pool...
#
#                                           host_about  unlisted
# 0  We are a couple with a big family and we love ...         0  \
# 1  Luna House B&B is part of the Luna House Hub, ...         1
# 2  World citizen looking forward to meet new peop...         0
#
#                                  cleaned_description
# 0  exclusive villa located quiet pinewood area co...  \
# 1  luna house b b part luna house hub located clo...
# 2  newly refurbished apartment swimming pool stun...
#
#                                  description_vectors        v_1        v_2
# 0  [35.13662564801052, 42.947640486992896, -1.106...  35.136626  42.947640  \
# 1  [34.154502129531465, 34.9295552438125, -8.8469...  34.154502  34.929555
# ...

# %% [markdown]
# ## Preprocessing Reviews

# %%
reviews_df = pd.read_csv('output/reviews_with_language.csv')
reviews_df['comments'] = reviews_df['comments'].astype('string')
reviews_df = reviews_df.dropna()

grouped = reviews_df.groupby(['index', 'language']).agg({'comments': 'count'})
grouped = grouped.reset_index()
final_grouped = grouped.groupby('index').agg({'language': 'nunique', 'comments': 'sum'})
final_grouped = final_grouped.reset_index()
final_grouped.columns = ['index', 'unique_languages_count', 'total_comments_count'] # rename the columns to the desired names


# Extracting and merging only English revies for now
reviews_df_eng = reviews_df[(reviews_df['language']=='en')]

grouped_eng = reviews_df_eng.groupby(['index']).agg({'comments': ['count', ' '.join]})
grouped_eng.columns = ['_'.join(col).strip() for col in grouped_eng.columns.values]
grouped_eng = grouped_eng.reset_index()

grouped_eng.columns = ['index', 'eng_comment_count', 'eng_reviews_merged'] # Rename the columns of the DataFrame

# Dataset constructed from Reviews
merged_reviews = pd.merge(final_grouped, grouped_eng, on='index', how='left')
merged_reviews
# Out:
#       index  unique_languages_count  total_comments_count  eng_comment_count
# 0         1                       7                    50               30.0  \
# 1         5                       6                    41               17.0
# 2         8                       8                   168              145.0
# 3         9                       6                    32               16.0
# 4        10                       3                    13               11.0
# ...     ...                     ...                   ...                ...
# 8461  12490                       7                    32               14.0
# 8462  12491                       4                    10                7.0
# 8463  12492                       9                   312              212.0
# 8464  12493                       5                    35               27.0
# 8465  12494                      10                   207              157.0
#
# ...

# %%
# Merging reviews to train_df
combined_df = pd.merge(combined_df, merged_reviews, on='index', how='left')
combined_df.head()
# Out:
#    index                                        description
# 0   7713  This exclusive villa, located in a quiet pinew...  \
# 1  11334  Luna House B&B is part of the Luna House Hub, ...
# 2   3537  Newly refurbished apartment with swimming pool...
# 3   4062  Nice studio for two people with one bathroom a...
# 4   2743  WHETHER FOR A SHORTER OR LONGER STAYS, I WANT ...
#
#                                           host_about  unlisted
# 0  We are a couple with a big family and we love ...         0  \
# 1  Luna House B&B is part of the Luna House Hub, ...         1
# 2  World citizen looking forward to meet new peop...         0
# 3  Hello, I’m Antonio and I want to welcome you i...         0
# 4  My name is Alexandre, I live in Lisbon and I l...         0
#
#                                  cleaned_description
# 0  exclusive villa located quiet pinewood area co...  \
# 1  luna house b b part luna house hub located clo...
# 2  newly refurbished apartment swimming pool stun...
# ...

# %%
combined_df['eng_reviews_cleaned'] = clean(combined_df['eng_reviews_merged'], lemmatize = True, stemmer = False)
combined_df.head()
# Out:
# 100%|███████████████████████████████████████| 9996/9996 [05:10<00:00, 32.21it/s]
#    index                                        description
# 0   7713  This exclusive villa, located in a quiet pinew...  \
# 1  11334  Luna House B&B is part of the Luna House Hub, ...
# 2   3537  Newly refurbished apartment with swimming pool...
# 3   4062  Nice studio for two people with one bathroom a...
# 4   2743  WHETHER FOR A SHORTER OR LONGER STAYS, I WANT ...
#
#                                           host_about  unlisted
# 0  We are a couple with a big family and we love ...         0  \
# 1  Luna House B&B is part of the Luna House Hub, ...         1
# 2  World citizen looking forward to meet new peop...         0
# 3  Hello, I’m Antonio and I want to welcome you i...         0
# 4  My name is Alexandre, I live in Lisbon and I l...         0
#
#                                  cleaned_description
# 0  exclusive villa located quiet pinewood area co...  \
# ...

# %%
combined_df['reviews_vectors'] = combined_df['eng_reviews_cleaned'].apply(get_sentence_vector)
combined_df.head(3)
# Out:
#    index                                        description
# 0   7713  This exclusive villa, located in a quiet pinew...  \
# 1  11334  Luna House B&B is part of the Luna House Hub, ...
# 2   3537  Newly refurbished apartment with swimming pool...
#
#                                           host_about  unlisted
# 0  We are a couple with a big family and we love ...         0  \
# 1  Luna House B&B is part of the Luna House Hub, ...         1
# 2  World citizen looking forward to meet new peop...         0
#
#                                  cleaned_description
# 0  exclusive villa located quiet pinewood area co...  \
# 1  luna house b b part luna house hub located clo...
# 2  newly refurbished apartment swimming pool stun...
#
#                                  description_vectors        v_1        v_2
# 0  [35.13662564801052, 42.947640486992896, -1.106...  35.136626  42.947640  \
# 1  [34.154502129531465, 34.9295552438125, -8.8469...  34.154502  34.929555
# ...

# %%
new_cols = pd.DataFrame(combined_df['reviews_vectors'].apply(pd.Series).values.tolist(), 
                        columns=['r_'+str(i+1) for i in range(50)])

# Concatenate horizontally (along axis=1) with different indexes
combined_df = pd.concat([combined_df.reset_index(drop=True), new_cols.reset_index(drop=True)], axis=1)

combined_df.head(5)
# Out:
#    index                                        description
# 0   7713  This exclusive villa, located in a quiet pinew...  \
# 1  11334  Luna House B&B is part of the Luna House Hub, ...
# 2   3537  Newly refurbished apartment with swimming pool...
# 3   4062  Nice studio for two people with one bathroom a...
# 4   2743  WHETHER FOR A SHORTER OR LONGER STAYS, I WANT ...
#
#                                           host_about  unlisted
# 0  We are a couple with a big family and we love ...         0  \
# 1  Luna House B&B is part of the Luna House Hub, ...         1
# 2  World citizen looking forward to meet new peop...         0
# 3  Hello, I’m Antonio and I want to welcome you i...         0
# 4  My name is Alexandre, I live in Lisbon and I l...         0
#
#                                  cleaned_description
# 0  exclusive villa located quiet pinewood area co...  \
# 1  luna house b b part luna house hub located clo...
# 2  newly refurbished apartment swimming pool stun...
# ...

# %%
feature_names = ['v_'+str(i+1) for i in range(50)] + ['r_'+str(i+1) for i in range(50)] + ['unique_languages_count', 'total_comments_count', 'eng_comment_count']

x_train = combined_df[feature_names]
x_train = x_train.fillna(0)

x_train
# Out:
#             v_1        v_2        v_3        v_4        v_5        v_6
# 0     35.136626  42.947640  -1.106369  -2.959592  35.337361 -24.277150  \
# 1     34.154502  34.929555  -8.846930  -7.521545  36.360019 -10.971707
# 2     40.250266  34.652338  -6.978866   1.241263  11.868687 -34.835922
# 3     40.432363  40.645558  -4.705836  -3.481639  21.099667 -21.982438
# 4     34.680662  24.131606  -1.834198 -14.697037   7.813480 -13.023907
# ...         ...        ...        ...        ...        ...        ...
# 9991  37.436634  40.390122 -11.201662  -8.903486   9.701048 -27.973777
# 9992  19.744406  28.070294  -6.992010  -6.261276  34.344053 -11.441753
# 9993  30.248591  37.528913   7.563411  -8.391753  23.839268 -18.109397
# 9994  32.931900  35.911243 -23.939777  -2.709645  24.472498 -31.184864
# 9995  20.011257  33.370648   4.731375   8.596707   8.007117 -17.548384
#
#             v_7        v_8        v_9       v_10  ...        r_44        r_45
# ...

# %%
# Scaling 
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)

# %% [markdown]
# ## Processing validation set in the same manner

# %%
val_df.head(3)
# Out:
#        index                                        description
# 4768    4769  This charming apartment on the first floor of ...  \
# 4384    4385  Charming villa with a private pool and tennis ...
# 11857  11858  One bedroom apartment inside a modern developm...
#
#                                               host_about  unlisted
# 4768   Easygoing person, always ready to present the ...         0  \
# 4384   Allure Villas is your go-to spot for renting V...         1
# 11857  Hey, this is Goncalo and Miku, your hosts in L...         0
#
#                                      cleaned_description
# 4768   charming apartment first floor typical cascais...
# 4384   charming villa private pool tennis table withi...
# 11857  one bedroom apartment inside modern developmen...

# %%
# Merging reviews to val_df
val_combined_df = pd.merge(val_df, merged_reviews, on='index', how='left')
val_combined_df.head()
# Out:
#    index                                        description
# 0   4769  This charming apartment on the first floor of ...  \
# 1   4385  Charming villa with a private pool and tennis ...
# 2  11858  One bedroom apartment inside a modern developm...
# 3   1282  Apartment in the heart of the city, between Pr...
# 4   2134  Amazing flat with two bedrooms in Restauradore...
#
#                                           host_about  unlisted
# 0  Easygoing person, always ready to present the ...         0  \
# 1  Allure Villas is your go-to spot for renting V...         1
# 2  Hey, this is Goncalo and Miku, your hosts in L...         0
# 3  Hi!\n\nI'm Laura, I'm 32yo, and I live with my...         0
# 4  We are Feels Like Home Holiday Rentals.\nA com...         0
#
#                                  cleaned_description  unique_languages_count
# 0  charming apartment first floor typical cascais...                     8.0  \
# ...

# %%
val_combined_df['eng_reviews_cleaned'] = clean(val_combined_df['eng_reviews_merged'], 
                                               lemmatize = True, stemmer = False)
#val_df[cols_to_scale] = scaler.transform(val_df[cols_to_scale]) # Note: just trannsform here

val_combined_df.head(3)
# Out:
# 100%|███████████████████████████████████████| 2500/2500 [01:18<00:00, 31.85it/s]
#    index                                        description
# 0   4769  This charming apartment on the first floor of ...  \
# 1   4385  Charming villa with a private pool and tennis ...
# 2  11858  One bedroom apartment inside a modern developm...
#
#                                           host_about  unlisted
# 0  Easygoing person, always ready to present the ...         0  \
# 1  Allure Villas is your go-to spot for renting V...         1
# 2  Hey, this is Goncalo and Miku, your hosts in L...         0
#
#                                  cleaned_description  unique_languages_count
# 0  charming apartment first floor typical cascais...                     8.0  \
# 1  charming villa private pool tennis table withi...                     NaN
# 2  one bedroom apartment inside modern developmen...                    10.0
#
#    total_comments_count  eng_comment_count
# ...

# %%
val_combined_df['description_vectors'] = val_combined_df['cleaned_description'].apply(get_sentence_vector)
new_cols = pd.DataFrame(val_combined_df['description_vectors'].apply(pd.Series).values.tolist(), 
                        columns=['v_'+str(i+1) for i in range(50)])
val_combined_df = pd.concat([val_combined_df.reset_index(drop=True), new_cols.reset_index(drop=True)], axis=1)


val_combined_df['reviews_vectors'] = val_combined_df['eng_reviews_cleaned'].apply(get_sentence_vector)
new_cols2 = pd.DataFrame(val_combined_df['reviews_vectors'].apply(pd.Series).values.tolist(), 
                        columns=['r_'+str(i+1) for i in range(50)])
val_combined_df = pd.concat([val_combined_df.reset_index(drop=True), new_cols2.reset_index(drop=True)], axis=1)

val_combined_df.head()
# Out:
#    index                                        description
# 0   4769  This charming apartment on the first floor of ...  \
# 1   4385  Charming villa with a private pool and tennis ...
# 2  11858  One bedroom apartment inside a modern developm...
# 3   1282  Apartment in the heart of the city, between Pr...
# 4   2134  Amazing flat with two bedrooms in Restauradore...
#
#                                           host_about  unlisted
# 0  Easygoing person, always ready to present the ...         0  \
# 1  Allure Villas is your go-to spot for renting V...         1
# 2  Hey, this is Goncalo and Miku, your hosts in L...         0
# 3  Hi!\n\nI'm Laura, I'm 32yo, and I live with my...         0
# 4  We are Feels Like Home Holiday Rentals.\nA com...         0
#
#                                  cleaned_description  unique_languages_count
# 0  charming apartment first floor typical cascais...                     8.0  \
# ...

# %%
x_val = val_combined_df[feature_names]
x_val = x_val.fillna(0)

# %%
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
# Out:
# (9996, 103) (9996,)
# (2500, 103) (2500,)

# %% [markdown]
# ## KNN model (on extended list of features)

# %%
# Model Building
modelknn = KNeighborsClassifier(n_neighbors = 7, 
                                metric = 'cosine', 
                                weights = 'distance')

modelknn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(metric='cosine', n_neighbors=7, weights='distance')

# %%
# Making preditions
y_pred = modelknn.predict(x_val)

# %%
# Model Evaluation
print(classification_report(y_pred, y_val, target_names = labels.keys()))
plot_cm(confusion_matrix(y_pred, y_val), labels.keys())
# Out:
#               precision    recall  f1-score   support
#
#       listed       0.91      0.91      0.91      1802
#     unlisted       0.77      0.76      0.76       698
#
#     accuracy                           0.87      2500
#    macro avg       0.84      0.84      0.84      2500
# weighted avg       0.87      0.87      0.87      2500

# %% [markdown]
# ## RandomForest (on extended list of features)

# %%
from sklearn.ensemble import RandomForestClassifier

model_forest = RandomForestClassifier(n_estimators=100, 
                                      class_weight={0: 0.7, 1: 0.3}, 
                                      random_state=42)

model_forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier(class_weight={0: 0.7, 1: 0.3}, random_state=42)

# %%
# Predicting
y_pred = model_forest.predict(x_val)

# %%
# Evaluation
print(classification_report(y_pred, y_val, target_names = labels.keys()))
plot_cm(confusion_matrix(y_pred, y_val), labels.keys())
# Out:
#               precision    recall  f1-score   support
#
#       listed       0.90      0.93      0.92      1761
#     unlisted       0.82      0.77      0.79       739
#
#     accuracy                           0.88      2500
#    macro avg       0.86      0.85      0.85      2500
# weighted avg       0.88      0.88      0.88      2500

# %% [markdown]
# ## XGBoost model (on extended list of features)

# %%
import xgboost as xgb

model_xgb = xgb.XGBClassifier(scale_pos_weight=0.25, random_state=123)
model_xgb.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=123, ...)

# %%
# Predicting
y_pred = model_xgb.predict(x_val)

# Evaluating
print(classification_report(y_pred, y_val, target_names = labels.keys()))
plot_cm(confusion_matrix(y_pred, y_val), labels.keys())
# Out:
#               precision    recall  f1-score   support
#
#       listed       0.93      0.87      0.90      1935
#     unlisted       0.64      0.78      0.70       565
#
#     accuracy                           0.85      2500
#    macro avg       0.78      0.83      0.80      2500
# weighted avg       0.87      0.85      0.86      2500
